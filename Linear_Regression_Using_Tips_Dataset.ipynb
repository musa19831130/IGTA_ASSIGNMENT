# %%
# importing all neccessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

import joblib

print('Libraries Loaded Successfully')
# Out:
# Libraries Loaded Successfully

# %% [markdown]
# # Uploading Tips Dataset

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Visualizing the Tips Dataset

# %%
plt.scatter(tips['total_bill'], tips['tip'])
plt.title("Meal Tip vs Total Bill")
plt.xlabel("Total_Bill")
plt.ylabel("Tip")
plt.show()

# %% [markdown]
# # In this case, their is no linear correlation between the dataset

# %% [markdown]
# # Spliting the dataset

# %%
# Split data into features (x) and target (y)
X = tips[["total_bill"]]
y = tips[["tip"]]

# Split our data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 26)

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[1.81402826],
#        [1.68169736],
#        [2.23097559],
#        [3.06802099],
#        [4.05000023],
#        [5.13910448],
#        [3.91871958],
#        [5.17901379],
#        [2.5985614 ],
#        [3.0890259 ],
#        [2.78760553],
#        [2.5334462 ],
#        [3.90716689],
#        [4.06365342],
#        [2.79075627],
#        [2.83591681],
#        [2.41791923],
#        [2.73299278],
#        [4.98786917],
#        [2.19736774],
#        [2.14800622],
#        [2.44522561],
#        [4.36822452],
#        [3.3169291 ],
#        [2.62271704],
#        [3.71287153],
#        [4.52261056],
#        [2.23727706],
#        [1.92325375],
#        [2.46728075],
#        [2.84746951],
#        [5.68313148],
#        [4.07730661],
#        [3.74122815],
#        [3.49547078],
#        [2.32444741],
#        [3.96282988],
#        [1.24269488],
#        [2.71303813],
#        [2.31394496],
#        [2.84011779],
#        [5.24622948],
#        [1.82137997],
#        [4.55726865],
#        [2.25828197],
#        [3.05121707],
#        [2.38431139],
#        [2.70463616],
#        [2.33915084]])

# %%
print(f"Slope (m): {model.coef_[0]}")
print(f"Intercept (b): {model.intercept_}")
# Out:
# Slope (m): [0.10502452]
# Intercept (b): [0.92026961]

# %% [markdown]
# # Evaluating the Model

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.4f}")
print(f"Root Squared Error: {rmse:.4f}")
print(f"R-Squared Score: {r2:.4f}")
# Out:
# Mean Squared Error: 1.0754
# Root Squared Error: 1.0370
# R-Squared Score: 0.1431

# %% [markdown]
# # Visualizing the predicted tip vs the total bill

# %%
plt.scatter(X_test, y_test, color='green', label="Tip")
plt.plot(X_test, y_pred, color='pink', label="Predicted")
plt.legend()
plt.show()

# %%
joblib.dump(model, 'meal_tip_predictor.joblib')
# Out:
# ['meal_tip_predictor.joblib']
