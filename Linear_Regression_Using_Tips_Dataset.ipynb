# %%
# import neccessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

import joblib

print('Libraries Loaded Successfully')
# Out:
# Libraries Loaded Successfully

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Visualizing the dataset
plt.scatter(tips['total_bill'], tips['tip'])
plt.title("Meal Tip vs Total Bill")
plt.xlabel("Total_Bill")
plt.ylabel("Tip")
plt.show()

# %%
# Split data into features (x) and target (y)
X = tips[["total_bill"]]
y = tips[["tip"]]

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[3.00185555],
#        [1.84133463],
#        [3.49862152],
#        [3.63935437],
#        [2.28558834],
#        [2.79915823],
#        [3.90716689],
#        [2.23097559],
#        [2.47253198],
#        [2.53554669],
#        [2.84116804],
#        [2.05138367],
#        [2.03878072],
#        [2.44102463],
#        [1.9778665 ],
#        [2.87792662],
#        [2.88527833],
#        [3.1866987 ],
#        [2.64792292],
#        [5.24622948],
#        [3.09322688],
#        [3.0890259 ],
#        [2.42317046],
#        [1.92325375],
#        [3.11528203],
#        [2.14800622],
#        [1.99887141],
#        [3.57528941],
#        [2.65212391],
#        [5.97930062],
#        [4.91855299],
#        [1.73315938],
#        [2.79075627],
#        [3.05121707],
#        [2.70253567],
#        [3.44925999],
#        [2.18371456],
#        [5.44787656],
#        [2.30239226],
#        [3.30117542],
#        [2.02407729],
#        [2.44522561],
#        [3.4356068 ],
# ...

# %%
print(f"Slope (m): {model.coef_[0]}")
print(f"Intercept (b): {model.intercept_}")
# Out:
# Slope (m): [0.10502452]
# Intercept (b): [0.92026961]

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.4f}")
print(f"Root Squared Error: {rmse:.4f}")
print(f"R-Squared Score: {r2:.4f}")
# Out:
# Mean Squared Error: 0.5491
# Root Squared Error: 0.7410
# R-Squared Score: 0.5607

# %%
plt.scatter(X_test, y_test, color='green', label="Tip")
plt.plot(X_test, y_pred, color='pink', label="Predicted")
plt.legend()
plt.show()

# %%
joblib.dump(model, 'meal_tip_predictor.joblib')
# Out:
# ['meal_tip_predictor.joblib']
